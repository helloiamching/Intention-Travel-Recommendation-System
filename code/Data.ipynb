# %% [markdown]
# https://googlemaps.github.io/google-maps-services-python/docs/index.html#googlemaps.Client.places

# %%
# !pip install -U googlemaps

# %%
import googlemaps
from datetime import datetime
import tqdm

gmaps = googlemaps.Client(key='AIzaSyC4nvz3-KMJ24qmg4VLtnI_zbHGgBjuGBM')

# %%
import googlemaps
from datetime import datetime
import tqdm

gmaps = googlemaps.Client(key='AIzaSyAaOt4Yueai5Oq9Z3fmzNBywoOVT-I1mp4')

# %%
cities = ["政大"]

# %%
geocode_result =gmaps.geocode(cities[0])
loc = geocode_result[0]['geometry']['location']

loc
# Out:
# {'lat': 25.0721568, 'lng': 121.5669693}

# %%
import csv
cities_Taipei = ["莊敬里","東榮里","三民里","新益里","富錦里","新東里","富泰里","介壽里","精忠里","東光里","龍田里","東昌里","東勢里","中華里","民有里","民福里","松基里","慈祐里","安平里","鵬程里","自強里","吉祥里","新聚里","復盛里","中正里","中崙里","美仁里","吉仁里","敦化里","復源里","復建里","復勢里","福成里","西村里","正和里","興隆里","中興里","新仁里","興雅里","敦厚里","廣居里","安康里","六藝里","雅祥里","五常里","五全里","永吉里","長春里","四育里","四維里","永春里","富台里","國業里","松隆里","松友里","松光里","中坡里","中行里","大道里","大仁里","景新里","惠安里","三張里","三犁里","六合里","泰和里","景聯里","景勤里","雙和里","嘉興里","黎順里","黎平里","黎忠里","黎安里","德安里","仁慈里","和安里","民炤里","仁愛里","義村里","民輝里","昌隆里","誠安里","光武里","龍坡里","龍泉里","古風里","古莊里","龍安里","錦安里","福住里","永康里","光明里","錦泰里","錦華里","龍圖里","新龍里","龍陣里","龍雲里","龍生里","住安里","義安里","通化里","通安里","臨江里","法治里","全安里","群賢里","群英里","虎嘯里","臥龍里","龍淵里","龍門里","大學里","芳和里","黎元里","黎孝里","黎和里","建安里","建倫里","敦安里","正聲里","敦煌里","華聲里","車層里","光信里","學府里","正守里","正義里","正得里","民安里","康樂里","中山里","聚盛里","集英里","聚葉里","恆安里","晴光里","圓山里","劍潭里","大直里","成功里","永安里","大佳里","新喜里","新庄里","新福里","松江里","新生里","中庄里","行政里","行仁里","行孝里","下埤里","江寧里","江山里","中吉里","中原里","興亞里","中央里","朱馥里","龍洲里","朱園里","埤頭里","朱崙里","力行里","復華里","金泰里","北安里","水源里","富水里","文盛里","林興里","河堤里","頂東里","網溪里","板溪里","螢圃里","螢雪里","永功里","永昌里","龍興里","忠勤里","廈安里","愛國里","南門里","龍光里","南福里","龍福里","新營里","建國里","光復里","黎明里","梅花里","幸福里","幸市里","東門里","文北里","文祥里","三愛里","玉泉里","建明里","建功里","建泰里","永樂里","朝陽里","星明里","光能里","大有里","延平里","雙連里","南芳里","民權里","景星里","隆和里","蓬萊里","國順里","國慶里","揚雅里","斯文里","鄰江里","至聖里","老師里","重慶里","保安里","福星里","萬壽里","西門里","新起里","菜園里","青山里","富民里","福音里","仁德里","富福里","頂碩里","雙園里","新忠里","新和里","糖
里","中興里","山德里","新路里","嶺頂里","龍壽里","舊路里","大崗里","文化里","南美里","幸福里","福源里","龍華里","迴龍里","新嶺里","大湖里","大華里","長庚里","新興里","文青里","楓福里","興仁里","福興里","瑞豐里","瑞發里","瑞德里","瑞祥里","廣興里","廣隆里","竹園里","霄裡里","茄苳里","高明里","白鷺里","大湳里","大安里","大興里","大和里","大同里","大成里","大義里","大忠里","大福里","大勇里","大信里","大華里","大仁里","大智里","瑞泰里","大昌里","大正里","大強里","大發里","大明里","大竹里","大慶里","大千里","大榮里","茄明里","高城里","瑞興里","大愛里","大宏里","大漢里","廣德里","龍友里","陸光里","永豐里","大順里","福元里","福德里","興中里","黃唐里","中山里","烏林里","高平里","凌雲里","八德里","三水里","上林里","中正里","龍潭里","高原里","九龍里","中興里","佳安里","三和里","三坑里","大平里","三林里","永興里","烏樹林里","百年里","龍祥里","聖德里","龍星里","上華里","武漢里","東興里","北興里","建林里","富林里","祥和里","渴望里","雙連里","高雙里","復旦里","廣興里","義民里","宋屋里","新勢里","新富里","北勢里","北興里","北貴里","平鎮里","南勢里","莊敬里","山峰里","湧光里","龍恩里","東社里","龍興里","貿易里","忠貞里","中正里","建安里","東勢里","東安里","新安里","鎮興里","義興里","湧豐里","湧安里","廣達里","福林里","金星里","廣仁里","新貴里","北富里","新榮里","華安里","金陵里","北安里","北華里","復興里","平興里","新英里","平安里","平南里","新屋里","新生里","後湖里","清華里","頭洲里","埔頂里","九斗里","社子里","東明里","石磊里","下埔里","下田里","石牌里","赤欄里","永興里","永安里","笨港里","深圳里","蚵間里","槺榔里","後庄里","大坡里","望間里","觀音里","白玉里","廣興里","大潭里","武威里","保生里","三和里","新興里","坑尾里","金湖里","藍埔里","大同里","大堀里","崙坪里","富源里","上大里","新坡里","廣福里","塔腳里","保障里","草漯里","樹林里","富林里","草新里","三民里","澤仁里","義盛里","霞雲里","長興里","三光里","奎輝里","華陵里","羅浮里","霞雲里"]

cities = cities_Taipei + cities_New_Taipei + cities_Taoyuan
results = []
places = []
ids = []
next_page_token = None

# %%
for city in cities_Taipei:
  city = city + " 台北市"
for city in cities_Taoyuan:
  city = city + " 桃園"
for city in cities_New_Taipei:
  city = city + " 新北市"

# %%
with open('tour_id_output_ewe.csv', 'w', newline='') as csvfile:
  writer = csv.writer(csvfile)
  writer.writerow(['Place_ID'])
  for city in cities:
    geocode_result = gmaps.geocode(city)
    if geocode_result:
      loc = geocode_result[0]['geometry']['location']
      ewe = gmaps.places_nearby(keyword="attraction",location=loc,radius=4000)
      for place in ewe['results']:

        writer.writerow([place['place_id']])

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd

#df_id_h = pd.read_csv("/content/hotels_id_output.csv")
#df_id_r = pd.read_csv("/content/restaurant_id_output.csv")
df_id_t = pd.read_csv("/content/tour_id_output_ewe.csv")

# %%
df_id = pd.read_csv("/content/tour_id_output_ewe.csv")

# %%
df= pd.read_csv("/content/data_output.csv")
df.loc[[2]]['reviews_text']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-04b8bee379cb> in <cell line: 1>()
# ----> 1 df= pd.read_csv("/content/data_output.csv")
#       2 df.loc[[2]]['reviews_text']
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df = df_id_r.duplicated()
df.value_counts()
# Out:
# True     33730
# False     4906
# dtype: int64

# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-

from tqdm import tqdm, trange
with open('tour_data_output.csv', 'w', newline='') as csvfile:
  writer = csv.writer(csvfile)
  writer.writerow(['place_id','name','business_status','wheelchair_accessible_entrance','type','rating','editorial_summary','user_ratings_total','price_level','formatted_phone_number','formatted_address','opening_hours','dine_in','delivery','location(lat,lng)','reviews_text','serves_breakfast','serves_brunch','serves_lunch','serves_dinner','serves_vegetarian_food'])
  for id in tqdm(df_id["Place_ID"]):
    awa = gmaps.place(place_id = id , reviews_no_translations=True ,fields=['name','business_status','wheelchair_accessible_entrance','editorial_summary','rating','serves_vegetarian_food','serves_breakfast','serves_brunch','serves_lunch','delivery','serves_dinner','type','editorial_summary','formatted_address','reviews','formatted_phone_number','price_level','geometry/location','place_id','vicinity','user_ratings_total','formatted_phone_number','opening_hours','reviews','dine_in'], language= 'zh_TW')['result']
    place_id = awa['place_id']
    name=awa['name']
    business_status = "NaN"
    opening_hours = "NaN"
    atype = "NaN"
    reviews_text = "NaN"
    wheelchair_accessible_entrance = "NaN"
    rating = "NaN"
    editorial_summary ="NaN"
    price_level = "NaN"
    location = "NaN"
    formatted_phone_number = "NaN"
    user_ratings_total = "NaN"
    dine_in = "NaN"
    ttype="NaN"
    serves_breakfast = "NaN"
    formatted_address = "NaN"
    delivery = "NaN"
    serves_lunch = "NaN"
    reviews_text = []
    serves_brunch = "NaN"
    serves_dinner = "NaN"
    serves_vegetarian_food = "NaN"
    if 'formatted_address' in awa:
      formatted_address = awa['formatted_address']
    if 'wheelchair_accessible_entrance' in awa:
      wheelchair_accessible_entrance = awa['wheelchair_accessible_entrance']
    if 'business_status' in awa:
      atype = awa['business_status']
    if 'types' in awa:
      ttype = awa['types']
    if 'rating' in awa:
      rating = awa['rating']
    if 'user_ratings_total' in awa:
      user_ratings_total = awa['user_ratings_total']
    if 'editorial_summary' in awa:
      editorial_summary = awa['editorial_summary']
    if 'price_level' in awa:
      price_level = awa['price_level']
    if 'formatted_phone_number' in awa:
      formatted_phone_number = awa['formatted_phone_number']
    if 'opening_hours' in awa:
      opening_hours = awa['opening_hours']
    if "dine_in" in awa:
      dine_in = awa['dine_in']
    if "delivery" in awa:
      delivery = awa['delivery']
    if 'geometry' in awa:
      location = awa['geometry']['location']
    if 'reviews' in awa:
      for review in range(0,len(awa['reviews'])):
        reviews_text.append(awa['reviews'][review]['text'])
    if 'serves_breakfast' in awa:
      serves_breakfast = awa['serves_breakfast']
    if 'serves_brunch' in awa:
      serves_brunch = awa['serves_brunch']
    if 'serves_vegetarian_food' in awa:
      serves_vegetarian_food = awa['serves_vegetarian_food']
    if 'serves_dinner' in awa:
      serves_dinner = awa['serves_dinner']
    if 'serves_lunch' in awa:
      serves_lunch = awa['serves_lunch']
    writer.writerow([place_id,name,business_status,wheelchair_accessible_entrance,ttype,rating,editorial_summary,user_ratings_total,price_level,formatted_phone_number,formatted_address,opening_hours,dine_in,delivery,location,reviews_text,serves_breakfast,serves_brunch,serves_lunch,serves_dinner,serves_vegetarian_food])
# Out:
# 100%|██████████| 32264/32264 [10:23<00:00, 51.73it/s]

# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-

from tqdm import tqdm, trange
with open('restaurant_data_output.csv', 'w', newline='') as csvfile:
  writer = csv.writer(csvfile)
  #writer.writerow(['place_id','user_ratings_total','address_components','rating','formatted_address'])
  writer.writerow(['place_id','user_ratings_total','rating','formatted_address'])
  for id in tqdm(df_id_r["Place_ID"]):
    awa = gmaps.place(place_id = id , reviews_no_translations=True ,language= 'zh_TW')['result']
    place_id = awa['place_id']
    rating = "NaN"
    address_components = "NaN"
    if 'formatted_address' in awa:
      formatted_address = awa['formatted_address']
    if 'rating' in awa:
      rating = awa['rating']
    if 'user_ratings_total' in awa:
      user_ratings_total = awa['user_ratings_total']
#    if awa['address_components'][3]:
#      address_components = awa['address_components'][3]
    writer.writerow([place_id,user_ratings_total,rating,formatted_address])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-6b9c5b709043> in <cell line: 5>()
#       7   #writer.writerow(['place_id','user_ratings_total','address_components','rating','formatted_address'])
#       8   writer.writerow(['place_id','user_ratings_total','rating','formatted_address'])
# ----> 9   for id in tqdm(df_id_r["Place_ID"]):
#      10     awa = gmaps.place(place_id = id , reviews_no_translations=True ,language= 'zh_TW')['result']
#      11     place_id = awa['place_id']
#
# NameError: name 'df_id_r' is not defined

# %%
gmaps.place(place_id = 'ChIJ1aAxzRCpQjQRUFCLQyeCIl8' , reviews_no_translations=True ,fields=['name','business_status','wheelchair_accessible_entrance','editorial_summary','rating','serves_vegetarian_food','serves_breakfast','serves_brunch','serves_lunch','serves_dinner','type','editorial_summary','formatted_address','reviews','international_phone_number','price_level','geometry/location','place_id','vicinity'], language= 'zh_TW')['result']

# %%
gmaps.place(place_id = 'ChIJmcWbolwXaTQR5j05_Ssl7t4' , reviews_no_translations=True , language= 'zh_TW')
# Out:
# {'html_attributions': [],
#  'result': {'address_components': [{'long_name': '學府路',
#     'short_name': '學府路',
#     'types': ['route']},
#    {'long_name': '大雅區',
#     'short_name': '大雅區',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': '台中市',
#     'short_name': '台中市',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '台灣', 'short_name': 'TW', 'types': ['country', 'political']},
#    {'long_name': '428', 'short_name': '428', 'types': ['postal_code']}],
#   'adr_address': 'No. 103, <span class="street-address">學府路</span><span class="locality">大雅區</span><span class="region">台中市</span><span class="country-name">台灣</span> <span class="postal-code">428</span>',
#   'business_status': 'OPERATIONAL',
#   'current_opening_hours': {'open_now': False,
#    'periods': [{'close': {'date': '2024-03-25', 'day': 1, 'time': '1100'},
#      'open': {'date': '2024-03-25', 'day': 1, 'time': '0600'}},
# ...

# %%
awa = gmaps.place(place_id = id , reviews_no_translations=True ,fields=['name','business_status','wheelchair_accessible_entrance','editorial_summary','rating','serves_vegetarian_food','serves_breakfast','serves_brunch','serves_lunch','serves_dinner','type','editorial_summary','formatted_address','reviews','formatted_phone_number','price_level','geometry/location','place_id','vicinity','user_ratings_total','formatted_phone_number','opening_hours','reviews'], language= 'zh_TW')['result']

# %%
awa

# %%
places = []
next_page_token = None
city = "臺北市"
geocode_result =gmaps.geocode(city)
loc = geocode_result[0]['geometry']['location']

places.append(gmaps.places_nearby(keyword="restaurant",location=loc,radius=20000,page_token=next_page_token)['results'])
next_page_token = gmaps.places_nearby(keyword="restaurant",location=loc,radius=20000,page_token=next_page_token)['next_page_token']

# %%
places.append(gmaps.places_nearby(keyword="restaurant",location=loc,radius=20000,page_token=next_page_token)['results'])
next_page_token = gmaps.places_nearby(keyword="restaurant",location=loc,radius=20000,page_token=next_page_token)['next_page_token']

# %%
places

# %%
conn = sqlite3.connect('mydatabase.db')


cursor = conn.cursor()

cursor.execute('''CREATE TABLE IF NOT EXISTS place_ID (
                    place_id TEXT
                )''')

# %%
for city in cities:
  geocode_result =gmaps.geocode(city)
  if geocode_result:
    loc = geocode_result[0]['geometry']['location']
    ewe = gmaps.places_nearby(keyword="restaurant",location=loc,radius=4000)
    for place in ewe['results']:
      data = place['place_id']
      cursor.execute("INSERT INTO place_ID VALUES (?)", (data,))
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-28-6900500e1dd8> in <cell line: 1>()
#       6     for place in ewe['results']:
#       7       data = place['place_id']
# ----> 8       cursor.execute("INSERT INTO place_ID VALUES (?)", (data,))
#
# ProgrammingError: Cannot operate on a closed cursor.

# %%
conn.commit()

# 關閉游標和資料庫連接
cursor.close()
conn.close()

# %%
with open('tourists_id_output.csv', 'w', newline='') as csvfile:
  writer = csv.writer(csvfile)
  writer.writerow(['Place_ID'])
  for city in cities:
    geocode_result = gmaps.geocode(city)
    if geocode_result:
      loc = geocode_result[0]['geometry']['location']
      ewe = gmaps.places_nearby(keyword="restaurant",location=loc,radius=4000)
      for place in ewe['results']:

        writer.writerow([place['place_id']])
# Out:
# ---------------------------------------------------------------------------
# ApiError                                  Traceback (most recent call last)
# <ipython-input-6-a443ba06b7d5> in <cell line: 1>()
#       3   writer.writerow(['Place_ID'])
#       4   for city in cities:
# ----> 5     geocode_result = gmaps.geocode(city)
#       6     if geocode_result:
#       7       loc = geocode_result[0]['geometry']['location']
#
# /usr/local/lib/python3.10/dist-packages/googlemaps/client.py in wrapper(*args, **kwargs)
#     443     def wrapper(*args, **kwargs):
#     444         args[0]._extra_params = kwargs.pop("extra_params", None)
# --> 445         result = func(*args, **kwargs)
#     446         try:
#     447             del args[0]._extra_params
#
# /usr/local/lib/python3.10/dist-packages/googlemaps/geocoding.py in geocode(client, address, place_id, components, bounds, region, language)
#      73         params["language"] = language
#      74
# ...
